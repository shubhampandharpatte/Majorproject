# %%
#EXPLORATORY DATA ANALYSIS
#DATASET:-"/content/Forbes_2000_top_company_CLNQ11.csv"

# %%
#1.Take the data and create dataframe
import pandas as pd
df = pd.read_csv('/content/Forbes_2000_top_company_CLNQ11.csv')
df
# Out:
#       2022 Ranking                          Organization Name  \
# 0                1                         Berkshire Hathaway
# 1                2                                       ICBC
# 2                3   Saudi Arabian Oil Company (Saudi Aramco)
# 3                4                             JPMorgan Chase
# 4                5                    China Construction Bank
# ...            ...                                        ...
# 1994          1995                                     Aperam
# 1995          1995  Shenzhen Feima International Supply Chain
# 1996          1997                                       NMDC
# 1997          1997                 Sichuan Changhong Electric
# 1998          1999                         Satellite Chemical
#
#                           Industry        Country  Year Founded  \
# 0           Diversified Financials  United States          1939
# 1                          Banking          China          1984
# ...

# %%
df.shape #1999 rows and 11 columns
# Out:
# (1999, 11)

# %%
df.size #Total number of elements in dataframe
# Out:
# 21989

# %%
df.info() #It gives the complete information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   2022 Ranking             1999 non-null   int64
#  1   Organization Name        1999 non-null   object
#  2   Industry                 1999 non-null   object
#  3   Country                  1999 non-null   object
#  4   Year Founded             1999 non-null   int64
#  5   CEO                      1999 non-null   object
#  6   Revenue (Billions)       1999 non-null   float64
#  7   Profits (Billions)       1999 non-null   float64
#  8   Assets (Billions)        1999 non-null   float64
#  9   Market Value (Billions)  1999 non-null   float64
#  10  Total Employees          1999 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 171.9+ KB

# %%
# To check the null values officially
df.isnull().sum()
# Out:
# 2022 Ranking               0
# Organization Name          0
# Industry                   0
# Country                    0
# Year Founded               0
# CEO                        0
# Revenue (Billions)         0
# Profits (Billions)         0
# Assets (Billions)          0
# Market Value (Billions)    0
# Total Employees            0
# dtype: int64

# %%
#I want to find out the exact count of unique elements in each and every column
df.nunique()
# Out:
# 2022 Ranking               1684
# Organization Name          1999
# Industry                     29
# Country                      57
# Year Founded                214
# CEO                        1963
# Revenue (Billions)         1587
# Profits (Billions)          688
# Assets (Billions)          1790
# Market Value (Billions)    1665
# Total Employees            1748
# dtype: int64

# %%
#VISUALISATION - SEABORN
#THIS VISUALISATION TELLS US ABOUT THE NUMBER OF PEOPLE SURVIVED and NOT SURVIVED
import seaborn as sns
import matplotlib.pyplot as plt#import the library
plt.figure(figsize=(15,15))
sns.histplot(x = 'Year Founded',data = df)
plt.title('Year Founded')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt#import the library
plt.figure(figsize=(15,15))
sns.countplot(x = 'Country',data = df)
plt.xticks(rotation=90)
plt.title('Number of Companies from all country ')
plt.show()

# %%
#Exact count of number of companies of each countries in list
df['Country'].value_counts()
# Out:
# United States           584
# China                   297
# Japan                   196
# South Korea              65
# United Kingdom           64
# Canada                   64
# India                    55
# France                   54
# Hong Kong                54
# Germany                  52
# Taiwan                   48
# Switzerland              40
# Sweden                   32
# Australia                30
# Italy                    26
# Netherlands              24
# Brazil                   23
# Russia                   23
# Spain                    21
# Ireland                  21
# Saudi Arabia             16
# Thailand                 14
# Israel                   13
# South Africa             13
# United Arab Emirates     13
# Denmark                  11
# Singapore                11
# Turkey                    9
# Austria                   9
# Finland                   9
# Luxembourg                9
# Mexico                    9
# Poland                    8
# ...

# %%
#Exact count of number of  companies of each industry in list
df['Industry'].value_counts()
# Out:
# Banking                             289
# Diversified Financials              146
# Construction                        127
# Materials                           117
# Oil & Gas Operations                106
# Insurance                           105
# Consumer Durables                    89
# Utilities                            83
# Business Services & Supplies         82
# Chemicals                            75
# IT Software & Services               73
# Food, Drink & Tobacco                73
# Transportation                       70
# Retailing                            69
# Drugs & Biotechnology                67
# Capital Goods                        59
# Technology Hardware & Equipment      56
# Health Care Equipment & Services     44
# Telecommunications Services          43
# Trading Companies                    37
# Semiconductors                       35
# Household & Personal Products        33
# Conglomerates                        29
# ...

# %%
#Exact count of number of  companies in particular year in list
df['Year Founded'].value_counts()
# Out:
# 0       96
# 1997    55
# 1998    40
# 1994    37
# 1996    37
#         ..
# 2021     1
# 1806     1
# 2022     1
# 1831     1
# 1861     1
# Name: Year Founded, Length: 214, dtype: int64

# %%
plt.figure(figsize=(15,20))
sns.barplot(data=df, x = "Revenue (Billions)", y = "Country")
plt.title('Revenue Vs Country',fontsize=25)
plt.xlabel("Revenue (Billions)", fontsize=25)
plt.ylabel("Countries", fontsize=25)
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.barplot(data=df, x = "Profits (Billions)", y = "Country")
plt.title('Profits Vs Country',fontsize=25)
plt.xlabel("Profits (Billions)", fontsize=25)
plt.ylabel("Countries", fontsize=25)
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.barplot(data=df, x = "Assets (Billions)", y = "Country")
plt.title('Assets Vs Country',fontsize=25)
plt.xlabel("Assets (Billions)", fontsize=25)
plt.ylabel("Countries", fontsize=25)
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.barplot(data=df, x = "Market Value (Billions)", y = "Country")
plt.title('Market Value Vs Country',fontsize=25)
plt.xlabel("Market Value (Billions)", fontsize=25)
plt.ylabel("Countries", fontsize=25)
plt.show()
